# %%
from examples.paper.initialize import *
import itertools
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn.apionly as sns
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression


data_name = 'givemecredit'
data_file = data_dir / ('%s/cs-training.csv' % (data_name))
output_dir = results_dir / data_name
raw_df = pd.concat([pd.read_csv(data_file, index_col=0), ])

# %%
raw_df.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1                 1                              0.766127   45
# 2                 0                              0.957151   40
# 3                 0                              0.658180   38
# 4                 0                              0.233810   30
# 5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  ...  \
# 1                                     2   0.802982  ...
# 2                                     0   0.121876  ...
# 3                                     1   0.085113  ...
# 4                                     0   0.036050  ...
# 5                                     1   0.024926  ...
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 1                               13                        0
# 2                                4                        0
# 3                                2                        1
# 4                                5                        0
# 5                                7                        0
#
#    NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 1                             6                                     0
# 2                             0                                     0
# 3                             0                                     0
# 4                             0                                     0
# 5                             1                                     0
#
#    NumberOfDependents
# 1                 2.0
# 2                 1.0
# 3                 0.0
# 4                 0.0
# 5                 0.0
#
# [5 rows x 11 columns]

# %% [markdown]
# # Load and Prepare Data

# %% [markdown]
# ### Split and train classifiers

# %%
# # 1. Out of Sample Costs
## sample the dataset
## preprocess and prepare

# original dataset. put aside 10,000 as holdout.
# remaining 40,000. split into age groups.
# over 35 should be included in both
# for the other add in the other.
# don't include age as a feature

y = 1 - raw_df['SeriousDlqin2yrs'].reset_index(drop=True)
X = raw_df.drop('SeriousDlqin2yrs', axis=1).fillna(0).reset_index(drop=True)

## split datasets for audit
X_clf, X_audit_holdout, y_clf, y_audit_holdout = train_test_split(X, y, test_size=.25)

X_clf_biased = X_clf.loc[lambda df: df['age'] >= 35] # .drop('age', axis=1)
y_clf_biased = y_clf.loc[X_clf_biased.index]

## train
clf_full = (
    LogisticRegressionCV(max_iter=1000, Cs=100, cv=5)
        .fit(X_clf, # .drop('age', axis=1),
             y_clf)
)
clf_age_limited = (
    LogisticRegressionCV(max_iter=1000, Cs=100, cv=5)
        .fit(X_clf_biased, y_clf_biased)
)

# %% [markdown]
# ### Run Predictions and store in a unified dataframe

# %%
coefficients = {}
intercept = {}
clfs = {'full': clf_full, 'downsampled': clf_age_limited}
for d in ['downsampled', 'full']:
    coefficients[d] = clfs[d].coef_[0]
    intercept[d] = clfs[d].intercept_[0]

# %% [markdown]
# # Run Audit

# %%
# actionset
action_set = ActionSet(X=X_audit_holdout)
action_set['age'].mutable = False
action_set['NumberOfDependents'].mutable = False
action_set['DebtRatio'].step_direction = -1

# %%
# utilization bounded
# RealEstate should be positive
# numtimes90 days > 0
# monthly income >0
# debt

p = 0.98

# run audit
audit_results = {}
for dataset in ['full', 'downsampled']:
    action_set.align(coefficients=coefficients[dataset])
    
    # audit
    auditor = RecourseAuditor(
        action_set,
        coefficients = coefficients[dataset],
        intercept = intercept[dataset] - (np.log(p / (1. - p))),
    )
    audit_results[dataset] = auditor.audit(X = X_audit_holdout)
# Out:
# HBox(children=(IntProgress(value=0, max=34199), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=33684), HTML(value='')))

# %% [markdown]
# ### Visualize

# %%
## mild processing
processed_data = {}
for training_run in ['full', 'downsampled']:
    processed_data[training_run] = (audit_results[training_run]
                .merge(X_audit_holdout['age'], right_index=True, left_index=True)
                .merge(y_audit_holdout.to_frame('y_true'), right_index=True, left_index=True)
                .replace([np.inf, -np.inf], np.nan)
                .assign(age_cut=lambda df: pd.cut(df['age'], np.arange(25, 75, 5)))
                .dropna()
               )

## plot
max_total_cost = combined['cost'].max()
plt.rc("font", size=20)
for y_true in [0, 1]:
    for training_run, label in [('downsampled', 'Age-limited Dataset'), ('full', 'Full Dataset')]:
        data = processed_data[training_run]       
        plt.figure(figsize=(4, 4))
        ax = sns.violinplot(
                x='age_cut', y='cost',
                data=data.loc[lambda df: df['y_true'] == y_true],
                linewidth = 0.5, cut=0,
                scale='width', color="gold",  inner='quartile'
                )
        
        ## formatting
        plt.ylim((0, max_total_cost))
        plt.ylabel("Cost of Recourse")
        plt.xlabel("Age")
        plt.title('Y-True: %s, %s' % (y_true, label))
        ax.set_ylim((0, 1))
        ax.set_xticks(np.arange(0, 14, 2)- 1,)
        ax.set_xticklabels( np.arange(20, 90, 10))
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        for l in ax.lines:
            l.set_linewidth(2.)
            l.set_linestyle('-')
            l.set_solid_capstyle('butt')
        ax.set_facecolor("white")
        plt.show()

# %% [markdown]
# # Generate Flipsets
#
# Let's identify one individual and look at the changes they'd have to make to make it past our threshold. First,
# we'll start with someone scored under the full model:

# %%
from IPython.display import HTML

# %%
## get flipset

## min-cost:
dataset = 'full'
scores = clfs[dataset].predict_proba(X_audit_holdout)[:, 1] # .drop('age', axis=1))[:, 1]
score_df = pd.Series(scores, index=X_audit_holdout.index).to_frame('y_full_score')

action_set.align(coefficients[dataset])  ## remember, if we're using the same actionset, we have to re-align
                                         ## it to use the right coefficients.
young_individuals = (processed_data[dataset]
    .merge(score_df, right_index=True, left_index=True)
    .loc[lambda df: df['age'] < 30]
    .loc[lambda df: df['y_full_score'] > .90]
    .loc[lambda df: df['y_full_score'] < .98 ]
    .index
    )

k = 4
fb = Flipset(
    x = X_audit_holdout.loc[young_individuals[k]].values, 
    action_set = action_set, 
    coefficients = coefficients[dataset],
    intercept = intercept[dataset] - (np.log(p / (1. - p))),
)
fb.populate(enumeration_type = 'distinct_subsets', total_items = 14)

# %%
HTML(fb.to_html())
# Out:
# <style  type="text/css" >
#     #T_eb53535c_6000_11e9_ab79_f26e0bc550fd tr {
#           background-color: white;
#     }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow0_col0 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow0_col1 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow0_col2 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow0_col3 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow1_col0 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow1_col1 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow1_col2 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow1_col3 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow2_col0 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow2_col1 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow2_col2 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow2_col3 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow3_col0 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow3_col1 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow3_col2 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow3_col3 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow4_col0 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow4_col1 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow4_col2 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow4_col3 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow5_col0 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow5_col1 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow5_col2 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow5_col3 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow6_col0 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow6_col1 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow6_col2 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow6_col3 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow7_col0 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow7_col1 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow7_col2 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow7_col3 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow8_col0 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow8_col1 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow8_col2 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow8_col3 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow9_col0 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow9_col1 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow9_col2 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow9_col3 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow10_col0 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow10_col1 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow10_col2 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow10_col3 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow11_col0 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow11_col1 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow11_col2 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow11_col3 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow12_col0 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow12_col1 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow12_col2 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow12_col3 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow13_col0 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow13_col1 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow13_col2 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow13_col3 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow14_col0 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow14_col1 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow14_col2 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow14_col3 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow15_col0 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow15_col1 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow15_col2 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow15_col3 {
#             background-color:  white;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow16_col0 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow16_col1 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow16_col2 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow16_col3 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow17_col0 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow17_col1 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow17_col2 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow17_col3 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow18_col0 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow18_col1 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab79_f26e0bc550fdrow18_col2 {
#             background-color:  lightgray;
#         }    #T_eb53535c_6000_11e9_ab

# %% [markdown]
# Now, we'll look at the changes they'd have to make if the model were trained without including young people:

# %%
dataset = 'downsampled'
k = 4
action_set.align(coefficients[dataset]) ## remember, if we're using the same actionset, we have to re-align
                                        ## it to use the right coefficients.
fb = Flipset(
    x = X_audit_holdout.loc[young_individuals[k]].values, 
    action_set = action_set, 
    coefficients = coefficients[dataset],
    intercept = intercept[dataset] - (np.log(p / (1. - p))),
)
fb.populate(enumeration_type = 'distinct_subsets', total_items = 14)

# %%
HTML(fb.to_html())
# Out:
# <style  type="text/css" >
#     #T_f446945e_6000_11e9_bc53_f26e0bc550fd tr {
#           background-color: white;
#     }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow0_col0 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow0_col1 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow0_col2 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow0_col3 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow1_col0 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow1_col1 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow1_col2 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow1_col3 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow2_col0 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow2_col1 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow2_col2 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow2_col3 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow3_col0 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow3_col1 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow3_col2 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow3_col3 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow4_col0 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow4_col1 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow4_col2 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow4_col3 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow5_col0 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow5_col1 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow5_col2 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow5_col3 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow6_col0 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow6_col1 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow6_col2 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow6_col3 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow7_col0 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow7_col1 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow7_col2 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow7_col3 {
#             background-color:  white;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow8_col0 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow8_col1 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow8_col2 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow8_col3 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow9_col0 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow9_col1 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow9_col2 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow9_col3 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow10_col0 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow10_col1 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow10_col2 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow10_col3 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow11_col0 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow11_col1 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow11_col2 {
#             background-color:  lightgray;
#         }    #T_f446945e_6000_11e9_bc53_f26e0bc550fdrow11_col3 {
#             background-color:  lightgray;
#         }</style><table id="T_f446945e_6000_11e9_bc53_f26e0bc550fd" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >features</th>        <th class="col_heading level0 col1" >x</th>        <th class="col_heading level0 col2" >to</th>        <th class="col_heading level0 col3" >x_new</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f446945e_6000_11e9_bc53_f26e0bc550fdlevel0_row0" class="row_heading level0 row0" rowspan=2>0</th>
#                         <th id="T_f446945e_6000_11e9_bc53_f26e0bc550fdlevel1_row0" class="row_heading level1 row0" >1</th>
#                         <td id="T_f446945e_6000_11e9_bc53_f26e0bc550fdrow0_col0" class="data row0 col0" >MonthlyIncome</td>
#                         <td id="T_f446945e_6000_11e9_bc53_f26e0bc550fdrow0_col1" class="data row0 col1" >1600</td>
#                         <td id="T_f446945e_6000_11e9_bc53_f26e0bc550fdrow0_col2" class="data row0 col2" >&#8594;</td>
#                         <td id="T_f446945e_6000_11e9_bc53_f26e0bc550fdrow0_col3" class="data row0 col3" >18330</td>
#             </tr>
#             <tr>
#                                 <th id="T_f446945e_6000_11e9_bc53_f26e0bc550fdlevel1_row1" class="row_heading level1 row1" >2</th>
#                         <td id="T_f446945e_6000_11e9_bc53_f26e0bc550fdrow1_col0" class="data row1 col0" >NumberOfTime60-89DaysPastDueNotWorse</td>
#                         <td id="T_f446945e_6000_11e9_bc53_f26e0bc550fdrow1_col1" class="data row1 col1" >1</td>
#                         <td id="T_f446945e_6000_11e9_bc53_f26e0bc550fdrow1_col2" class="data row1 col2" >&#8594;</td>
#                         <td id="T_f446945e_6000_11e9_bc53_f26e0bc550fdrow1_col3" class="data row1 col3" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_f446945e_6000_11e9_bc53_f26e0bc550fdlevel0_row2" class="row_heading level0 row2" rowspan=3>1</th>
#                         <th id="T_f446945e_6000_11e9_bc53_f26e0bc550fdlevel1_row2" class="row_heading level1 row2" >1</th>
#                         <td id="T_f446945e_6000_11e9_bc53_f26e0bc550fdrow2_col0" class="data row2 col0" >RevolvingUtilizationOfUnsecuredLines</td>
#                         <td id="T_f446945e_6000_11e9_bc53_f26e0bc550fdrow2_col1" class="data row2 col1" >0.107198</td>
#                         <td id="T_f446945e_6000_11e9_bc53_f26e0bc550fdrow2_col2" class="data row2 col2" >&#8594;</td>
#                         <td id="T_f446945e_6000_11e9_bc53_f26e0bc550fdrow2_col3" class="data row2 col3" >0.109214</td>
#             </tr>
#             <tr>
#                                 <th id="T_f446945e_6000_11e9_bc53_f26e0bc550fdlevel1_row3" class="row_heading level1 row3" >2</th>
#                         <td id="T_f446945e_6000_11e9_bc53_f26e0bc550fdrow3_col0" class="data row3 col0" >MonthlyIncome<

# %% [markdown]
# Not only do they have less options, but many of them are pretty ridiculous.
